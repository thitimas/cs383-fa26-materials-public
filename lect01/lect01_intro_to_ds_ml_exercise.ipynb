# %% [markdown]
# # CS383: Data Science and Machine Learning
# ## Lecture 1 Exercises — Reflection and Hands-On Data Exploration
#
# **Make a copy of this notebook before you start** (do not edit this original). This notebook has no code in it yet -- Lecture 1 is unplugged, and we start writing code together in Lecture 2. Answer each question directly in the response cells. Exercise 2 has you exploring a real, live dataset directly in your browser -- no code, no downloads, no account needed.

# %% [markdown]
# ---
#
# ## Exercise 1 — Reflection (Exit Ticket)
#
# Answer the following in your own words.
#
# 1. What is the difference between supervised and unsupervised learning? Give one real-world example of each that we haven't already used in class.
# 2. Why isn't `zip_code` a good example of numerical data, even though it's made of digits?
# 3. Of the 8 steps in the data science workflow, which do you think will be hardest for you personally, and why?
# 4. How did the sorting activity differ from the Thai character activity, in terms of what you were given to work with?
# 5. What question do you still have about data science or ML before we start writing code in Lecture 2?

# %% [markdown]
# **Your responses:**
#
# 1.
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ---
#
# ## Exercise 2 — Explore a Real Dataset
#
# Everything so far today has been about data in the abstract. This exercise is the opposite: you're going
# to open an actual, live, public dataset and poke around in it yourself -- **no code, no download, no
# account required.**
#
# Open this dataset in a new tab: **[NYC 311 Service Requests](https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2020-to-Present/erm2-nwe9)**
#
# This is the same real-world source the borough / complaint type / resolution time examples in today's
# Types of Data diagram came from -- except now you're looking at the real thing instead of a picture of it.
#
# Click **View Data** (or the grid/table icon) to see actual rows. You can click a column header to sort,
# and most columns have a filter icon to narrow down what you're looking at -- try both before you answer
# the questions below.

# %% [markdown]
# ### Step 1 — Read the columns
#
# Scroll across the column headers (don't worry about seeing every single one). List **three** column
# names you find, and for each one, classify it using today's Types of Data framework: qualitative or
# quantitative, and then the more specific bucket (nominal, ordinal, discrete, or continuous).

# %% [markdown]
# **Your answer:**
#
# | Column name | Qualitative or Quantitative | Specific type (nominal / ordinal / discrete / continuous) |
# |---|---|---|
# | | | |
# | | | |
# | | | |

# %% [markdown]
# ### Step 2 — Filter it yourself
#
# Pick one column and use the portal's own filter or sort tool on it (for example: filter `Complaint Type`
# down to one specific value, or sort `Borough` alphabetically). Report what you did and what you noticed
# in the results -- a specific number, a specific row, or a pattern you saw is more useful here than a
# general impression.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ### Step 3 — Find something messy
#
# Real data is rarely clean. Scroll or filter until you spot something that looks off: a blank/missing
# cell, an inconsistent spelling or capitalization, a date that looks wrong, a category that seems to
# overlap with another one, or anything else that would need to be cleaned up before you could analyze it
# properly. Describe exactly what you found and where.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ### Step 4 — Real data vs. toy data
#
# Datasets like Iris or Titanic (common in most intro ML tutorials) are small, pre-cleaned, and have no
# messiness left to find. Based on what you just saw, write two or three sentences on what's different
# about working with a dataset like this one -- and why that difference might matter once you're building
# a model on top of it, not just looking at it.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ### Big idea
# > The dataset you just explored is the same kind of real, messy, live data this entire course is built
# > around -- you'll be back in datasets like this one starting in Lecture 3, except then you'll be cleaning
# > and joining it in code instead of clicking around a web page.

# %% [markdown]
# ---
#
# ## Optional Challenge
#
# Pick one product or app you use regularly that you suspect uses machine learning (e.g. a music app's recommendations, a photo app's face grouping, a food delivery app's ETA estimate, a spam filter).

# %% [markdown]
# ### Step 1 — Describe the input and output
#
# Describe, in plain language, what you think the ML model's input (features) and output (prediction) might be.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ### Step 2 — Supervised or unsupervised?
#
# Is it more likely supervised or unsupervised? Justify your guess.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ### Step 3 — What data type is the output?
#
# What data type would the main output be — numerical, categorical, or something else?

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ### Step 4 — Think about representation
#
# What would go wrong if the model's training data only ever included examples from one type of user?

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ### Big idea
# > Every real ML system starts with these same questions — problem framing, data type, and who it might
# > fail to represent — long before anyone writes a line of code. We'll formalize problem framing properly
# > starting in Week 6.
